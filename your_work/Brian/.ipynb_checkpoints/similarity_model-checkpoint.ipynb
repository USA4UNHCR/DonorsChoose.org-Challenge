# %%
import os
import random
import logging
from pprint import pprint
from collections import defaultdict

import gensim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
clean_df = pd.read_csv("/Users/brianxia/Desktop/ProjectRepo/hackaworld/clean_data.csv")
clean_df.head(5)
# Out:
#    Unnamed: 0                 project_hashed_id  \
# 0           1  4cd4a67235aa9ecfa559f9e5401dfb1b
# 1           6  3e376dbbb12c90fdb07b7cec1267c766
# 2           7  49aa7371e585fe5997b96fd9ff1d1432
# 3           8  176db972a6626216078d56781e329ff0
# 4           9  d46ced729e3ac305d74fcaad3169e15d
#
#                                   project_title  \
# 0                                   Engineering
# 1                  Amazing Electrical Engineers
# 2  A Rug Needed So Everyone Can Have Some Space
# 3                         STEM Makers Mentality
# 4                                  Hands Coding
#
#                                    project_essay_one  \
# 0  student attend computer class every week speci...
# 1  student attend computer class every week speci...
# 2  student come school area high poverty despite ...
# 3  student attend computer class every week speci...
# 4  student attend computer class every week speci...
#
#                                    project_essay_two  project_cost  \
# 0  student enjoy creating testing safe electrical...      0.000603
# 1  student enjoy learning activity using basic ju...      0.000626
# 2  morning start morning meeting classroom way he...      0.001561
# 3  lego kit make difference student learning givi...      0.001147
# 4  student enjoy completing activity hour code ch...      0.000925
#
#   project_posted_date project_funded_date  \
# 0          2018-10-23          2018-10-30
# 1          2018-04-23          2018-04-24
# 2          2018-03-09          2018-03-27
# 3          2018-01-10          2018-01-12
# 4          2017-11-06          2017-11-06
#
#                                project_impact_letter  \
# 0
# 1  Thank much making Amazing Electrical Engineers...
# 2  I want thank generous support help rug needed ...
# 3  Many thanks generous donation We Do robotics k...
# 4  Thank generous donation Hands On Coding projec...
#
#               project_subj_cat_tree      ...      Instructional Technology  \
# 0                    Math & Science      ...                      0.028571
# 1                    Math & Science      ...                      0.000000
# 2                  Applied Learning      ...                      0.000000
# 3                    Math & Science      ...                      0.000000
# 4  Math & Science, Music & The Arts      ...                      0.028571
#
#    Lab Equipment Musical Instruments Other Reading Nooks, Desks & Storage  \
# 0       0.000000                 0.0   0.0                       0.000000
# 1       0.012048                 0.0   0.0                       0.000000
# 2       0.000000                 0.0   0.0                       0.025641
# 3       0.000000                 0.0   0.0                       0.000000
# 4       0.000000                 0.0   0.0                       0.000000
#
#   Sports & Exercise Equipment project_posted_datetime project_funded_datetime  \
# 0                         0.0              2018-10-23              2018-10-30
# 1                         0.0              2018-04-23              2018-04-24
# 2                         0.0              2018-03-09              2018-03-27
# 3                         0.0              2018-01-10              2018-01-12
# 4                         0.0              2017-11-06              2017-11-06
#
#    is_funded  days_to_fund
# 0       True         0.028
# 1       True         0.004
# 2       True         0.072
# 3       True         0.008
# 4       True         0.000
#
# [5 rows x 41 columns]

# %%
clean_df.loc[clean_df["project_title"].isna(), "project_title"] = " "
clean_df.loc[clean_df["project_essay_one"].isna(), "project_essay_one"] = " "
clean_df.loc[clean_df["project_essay_two"].isna(), "project_essay_two"] = " "
clean_df.loc[clean_df["project_impact_letter"].isna(), "project_impact_letter"] = " "
clean_df.loc[clean_df["project_subj_subcat_tree"].isna(), "project_subj_subcat_tree"] = " "

# %%
from collections import defaultdict
teachers = clean_df.groupby("teacher_hashed_id")["project_hashed_id", 
                                                 "project_title", 
                                                 "project_essay_one", 
                                                 "project_essay_two", 
                                                 "project_impact_letter", 
                                                 "school_hashed_id", 
                                                 "project_posted_date", 
                                                 "project_funded_date", 
                                                 "project_subj_cat_tree", 
                                                 "project_subj_subcat_tree", 
                                                 "project_grade_cat", 
                                                 "project_resource_type"].apply(lambda x: x.to_dict("records")).to_dict()
teachers = defaultdict(list, teachers)

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def tokenize(text):
    text = text.lower().split()
    return text

# %%
class TeacherDocs(object):
    
    def __init__(self):
        pass
    
    def __iter__(self):
        # Open the project file
        for teacher in teachers:
            all_text = []
            for rec in teachers[teacher]:
                # Load the title & essays
                all_text += tokenize(rec["project_title"])
                all_text += tokenize(rec["project_essay_one"])
                all_text += tokenize(rec["project_essay_two"])
                all_text += tokenize(rec["project_impact_letter"])
                # Load the meta data by creating unique tokens from values
#                 all_text += ["_".join(rec["subj_cat"].strip().lower().split())]
                all_text += ["_".join(rec["project_subj_subcat_tree"].strip().lower().split())]
#                 all_text += ["_".join(rec["grade_cat"].strip().lower().split())]
#                 all_text += ["_".join(rec["resc_type"].strip().lower().split())]
#             print((all_text, [teacher]))
#             break
            # Return all the text for the teacher
            yield gensim.models.doc2vec.TaggedDocument(all_text, [teacher])

# %%
# doc2vec params
models_dir = "/Users/brianxia/Desktop/ProjectRepo/hackaworld/model"
fname = "clean_data.csv"
window = 5
size = 100
iterations = 1

# bust_cache = True
bust_cache = False
model_path = os.path.join(models_dir, 'd2v_f-{}_s-{}_w-{}.model'.format(fname.split()[0],size, window))

# Build the model if it doesnt already exist
if not os.path.exists(model_path) or bust_cache:
    teacherlines = TeacherDocs() 
    model = gensim.models.doc2vec.Doc2Vec(size=size, min_count=5, window=window, iter=iterations,  workers=8)        
    model.build_vocab(teacherlines)
    model.train(teacherlines, total_examples=model.corpus_count, epochs=model.iter)
    model.save(model_path) 
else:
    model = gensim.models.doc2vec.Doc2Vec.load(model_path)
# Out:
# 2018-11-07 00:45:38,388 : INFO : collecting all words and their counts
# 2018-11-07 00:45:38,389 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-11-07 00:45:39,725 : INFO : PROGRESS: at example #10000, processed 4715293 words (3530903/s), 31316 word types, 10000 tags
# 2018-11-07 00:45:41,207 : INFO : PROGRESS: at example #20000, processed 9641330 words (3325996/s), 41169 word types, 20000 tags
# 2018-11-07 00:45:42,733 : INFO : PROGRESS: at example #30000, processed 14606502 words (3255362/s), 48509 word types, 30000 tags
# 2018-11-07 00:45:44,051 : INFO : PROGRESS: at example #40000, processed 19416073 words (3650118/s), 54484 word types, 40000 tags
# 2018-11-07 00:45:45,362 : INFO : PROGRESS: at example #50000, processed 24184479 words (3638995/s), 59548 word types, 50000 tags
# 2018-11-07 00:45:46,777 : INFO : PROGRESS: at example #60000, processed 29026093 words (3422610/s), 64055 word types, 60000 tags
# 2018-11-07 00:45:48,275 : INFO : PROGRESS: at example #70000, processed 33899867 words (3255278/s), 68224 word types, 70000 tags
# 2018-11-07 00:45:49,667 : INFO : PROGRESS: at example #80000, processed 38889690 words (3588872/s), 72323 word types, 80000 tags
# 2018-11-07 00:45:51,090 : INFO : PROGRESS: at example #90000, processed 43659290 words (3353195/s), 75811 word types, 90000 tags
# 2018-11-07 00:45:52,467 : INFO : PROGRESS: at example #100000, processed 48440592 words (3474060/s), 79358 word types, 100000 tags
# 2018-11-07 00:45:53,942 : INFO : PROGRESS: at example #110000, processed 53235347 words (3251302/s), 82671 word types, 110000 tags
# 2018-11-07 00:45:55,387 : INFO : PROGRESS: at example #120000, processed 58081437 words (3357177/s), 85921 word types, 120000 tags
# 2018-11-07 00:45:56,894 : INFO : PROGRESS: at example #130000, processed 62982764 words (3253444/s), 89177 word types, 130000 tags
# 2018-11-07 00:45:58,391 : INFO : PROGRESS: at example #140000, processed 67761286 words (3193497/s), 92105 word types, 140000 tags
# 2018-11-07 00:45:59,978 : INFO : PROGRESS: at example #150000, processed 72846391 words (3206087/s), 94866 word types, 150000 tags
# 2018-11-07 00:46:01,533 : INFO : PROGRESS: at example #160000, processed 77742825 words (3150245/s), 97641 word types, 160000 tags
# 2018-11-07 00:46:03,129 : INFO : PROGRESS: at example #170000, processed 82662074 words (3085008/s), 100271 word types, 170000 tags
# 2018-11-07 00:46:04,724 : INFO : PROGRESS: at example #180000, processed 87674488 words (3143450/s), 102894 word types, 180000 tags
# 2018-11-07 00:46:06,262 : INFO : PROGRESS: at example #190000, processed 92545026 words (3169367/s), 105400 word types, 190000 tags
# 2018-11-07 00:46:07,793 : INFO : PROGRESS: at example #200000, processed 97422412 words (3187726/s), 107850 word types, 200000 tags
# 2018-11-07 00:46:09,382 : INFO : PROGRESS: at example #210000, processed 102341151 words (3097380/s), 110148 word types, 210000 tags
# 2018-11-07 00:46:10,913 : INFO : PROGRESS: at example #220000, processed 107148460 words (3141348/s), 112554 word types, 220000 tags
# 2018-11-07 00:46:12,559 : INFO : PROGRESS: at example #230000, processed 111979009 words (2935529/s), 114839 word types, 230000 tags
# 2018-11-07 00:46:14,007 : INFO : PROGRESS: at example #240000, processed 116846070 words (3363458/s), 117084 word types, 240000 tags
# 2018-11-07 00:46:15,362 : INFO : PROGRESS: at example #250000, processed 121680872 words (3570802/s), 119262 word types, 250000 tags
# 2018-11-07 00:46:16,981 : INFO : PROGRESS: at example #260000, processed 126584558 words (3029338/s), 121437 word types, 260000 tags
# 2018-11-07 00:46:18,372 : INFO : PROGRESS: at example #270000, processed 131442668 words (3494383/s), 123445 word types, 270000 tags
# 2018-11-07 00:46:19,169 : INFO : collected 124612 word types and 275623 unique tags from a corpus of 275623 examples and 134188602 words
# 2018-11-07 00:46:19,170 : INFO : Loading a fresh vocabulary
# 2018-11-07 00:46:19,290 : INFO : min_count=5 retains 47671 unique words (38% of original 124612, drops 76941)
# 2018-11-07 00:46:19,291 : INFO : min_count=5 leaves 134065999 word corpus (99% of original 134188602, drops 122603)
# 2018-11-07 00:46:19,448 : INFO : deleting the raw counts dictionary of 124612 items
# 2018-11-07 00:46:19,453 : INFO : sample=0.001 downsamples 51 most-common words
# 2018-11-07 00:46:19,454 : INFO : downsampling leaves estimated 116567248 word corpus (86.9% of prior 134065999)
# 2018-11-07 00:46:19,602 : INFO : estimated required memory for 47671 words and 100 dimensions: 227346100 bytes
# 2018-11-07 00:46:19,602 : INFO : resetting layer weights
# /Users/brianxia/anaconda2/envs/hackaworld/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
words/s, in_qsize 16, out_qsize 0
# 2018-11-07 00:48:12,205 : INFO : EPOCH 1 - PROGRESS: at 96.81% examples, 1030216 words/s, in_qsize 16, out_qsize 0
# 2018-11-07 00:48:13,206 : INFO : EPOCH 1 - PROGRESS: at 97.73% examples, 1030194 words/s, in_qsize 15, out_qsize 0
# 2018-11-07 00:48:14,213 : INFO : EPOCH 1 - PROGRESS: at 98.60% examples, 1030327 words/s, in_qsize 15, out_qsize 0
# 2018-11-07 00:48:15,217 : INFO : EPOCH 1 - PROGRESS: at 99.50% examples, 1030169 words/s, in_qsize 15, out_qsize 0
# 2018-11-07 00:48:15,736 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-11-07 00:48:15,741 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-11-07 00:48:15,748 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-11-07 00:48:15,758 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-11-07 00:48:15,773 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-07 00:48:15,778 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-07 00:48:15,779 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-07 00:48:15,792 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-07 00:48:15,792 : INFO : EPOCH - 1 : training on 134188602 raw words (115704766 effective words) took 112.3s, 1030167 effective words/s
# 2018-11-07 00:48:15,793 : INFO : training on a 134188602 raw words (115704766 effective words) took 112.3s, 1029978 effective words/s
# 2018-11-07 00:48:15,796 : INFO : saving Doc2Vec object under /Users/brianxia/Desktop/ProjectRepo/hackaworld/model/d2v_f-clean_data.csv_s-100_w-5.model, separately None
# 2018-11-07 00:48:15,797 : INFO : storing np array 'vectors_docs' to /Users/brianxia/Desktop/ProjectRepo/hackaworld/model/d2v_f-clean_data.csv_s-100_w-5.model.docvecs.vectors_docs.npy
# 2018-11-07 00:48:17,744 : INFO : saved /Users/brianxia/Desktop/ProjectRepo/hackaworld/model/d2v_f-clean_data.csv_s-100_w-5.model

# %%
t = clean_df.teacher_hashed_id.tolist()
orig_docs = (clean_df['project_subj_subcat_tree'].apply(lambda x: "_".join(x.strip().lower().split())) + " " + 
             clean_df['project_title'] + " " + 
             clean_df['project_essay_one'] + " " + 
             clean_df['project_essay_two'] + " " + 
             clean_df['project_impact_letter']).tolist()

# %%
# Use only unigrams since doc2vec is operating on unigram tokens
vectorizer = TfidfVectorizer(stop_words=u'english', ngram_range=(1,1), max_features=25000)
# Transform the input features
docs = vectorizer.fit_transform(orig_docs)

# %% [markdown]
# Functions to get word weights per document

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %% [markdown]
# Word cloud plotting

# %%
# Global configuration for matplotlib figures
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['figure.facecolor'] = '#FFFFFF00'
plt.rcParams['axes.facecolor'] = '#FF00000F'

# %%
# Load the feature names
# you only needs to do this once, this is a mapping of index to 
feature_names=vectorizer.get_feature_names()

# %%
def show_wc(teacher_index, print_words=True):
    # Word cloud
    wc = WordCloud(background_color="white", max_words=2000, width = 2048,height = 720)
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(docs[teacher_index].tocoo())
    #extract only the top n; n here is 10
    keywords=extract_topn_from_vector(feature_names,sorted_items,10)
    # now print the results
    if print_words:
        print("\n===Keywords===")
        for k in keywords:
            print(k,keywords[k])
    keywords=extract_topn_from_vector(feature_names,sorted_items,100)
    weights = {k: keywords[k] for k in keywords}
    wc.generate_from_frequencies(weights)
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Load the model, generate random recommendations and visualize

# %% [markdown]
# First pick a random teacher as an anchor

# %%
random_teacher = random.choice(list(teachers.keys()))

print("--- Current logged in teacher (anchor) ---")
print("Teacher id: {}".format(random_teacher))
# Print all the projects
for i in range(len(teachers[random_teacher])):
    print(" ---- Project num - {} ----".format(i+1))
    print("Project Id: {}".format(teachers[random_teacher][i]["project_hashed_id"]))
    print("School: {}".format(teachers[random_teacher][i]["school_hashed_id"]))
    print("Posted: {}".format(teachers[random_teacher][i]["project_posted_date"]))
    print("Funded: {}".format(teachers[random_teacher][i]["project_funded_date"]))
    print("Grade : {}".format(teachers[random_teacher][i]["project_grade_cat"]))
    print("Subj  : {}".format(teachers[random_teacher][i]["project_subj_cat_tree"]))
    print("-- free text --")
    print("Title: {}".format(teachers[random_teacher][i]["project_title"]))
    print("Essay1: {}".format(teachers[random_teacher][i]["project_essay_one"]))
    print("Essay2: {}".format(teachers[random_teacher][i]["project_essay_two"]))
    print(" ---- End of project - {} ----".format(i))
# Out:
# --- Current logged in teacher (anchor) ---
# Teacher id: 76b1cf5821e09bfe9e01aee7655979a7
#  ---- Project num - 1 ----
# Project Id: cbfee285373180a8241fd2af9f6b9c03
# School: 14a9307da850c4e35a22a87cf6b13121
# Posted: 2018-09-05
# Funded: 2018-10-26
# Grade : 0.6666666666666666
# Subj  : History & Civics
# -- free text --
# Title: Help Make History Come Alive With Google Cardboard
# Essay1: powerful discover impact history peer research show classroom engagement increase improves student learning actively involved lesson rather passive listener student class love collaborate project find deeper meaning strive create environment emphasizes collaboration exchange idea engage student meaningful project around minnesota history student love take charge learning active engaging subject matter
# Essay2: google cardboard allow student ability take field trip place never thought possible create entirely new perspective historical event put center instead outside looking textbook instead reading native american tipi student able go inside one instead learning civil right march student able middle one google cardboard open whole new world student think critically collaboratively engage lesson experience history interactive way
#  ---- End of project - 0 ----
#  ---- Project num - 2 ----
# Project Id: 265a4a27b7d6598f0639fa567d5c05f0
# School: 14a9307da850c4e35a22a87cf6b13121
# Posted: 2018-08-10
# Funded: 2018-09-07
# Grade : 0.6666666666666666
# Subj  : History & Civics
# -- free text --
# Title: Social Studies School Supplies
# Essay1: powerful discover impact history peer research show classroom engagement increase improves student learning actively involved lesson rather passive listener student class love collaborate project find deeper meaning strive create environment emphasizes collaboration exchange idea engage student meaningful project around minnesota history student love take charge learning active engaging subject matter
# Essay2: currently student unequipped learn lack basic school supply necessary learn classroom student thrive able express creativity social study number different modality incorporating hand learning opportunity classroom allow student express way adding marker chart paper highlighter classroom student able collaborate project graphic organizer class work material create exciting learning environment also engage student learning
#  ---- End of project - 1 ----

# %% [markdown]
# Visualize the word cloud for the teacher

# %%
show_wc(t.index(random_teacher))
# Out:
# ===Keywords===
# cardboard 0.376
# history 0.334
# google 0.268
# tipi 0.234
# instead 0.228
# student 0.158
# passive 0.149
# minnesota 0.146
# listener 0.14
# emphasizes 0.139

# %% [markdown]
# next load similar items

# %%
# Load top 3 most similar by content. Ignore the first cos its the same teacher
top = 100
sim_teachers = model.docvecs.most_similar(random_teacher, topn=top+1)[1:]
# Out:
# 2018-11-07 01:14:27,030 : INFO : precomputing L2-norms of doc weight vectors

# %% [markdown]
# Print out top3 recommendations one by one (to keep visuals without the need to scroll)

# %%
c = 0
sim_teacher, sim_score = sim_teachers[c]
print("Rank - {}\nId - {}\n Score - {}".format(c+1, sim_teacher, sim_score))
for i in range(len(teachers[sim_teacher])):
    print(" ---- Project num - {} ----".format(i+1))
    print("Project Id: {}".format(teachers[sim_teacher][i]["project_hashed_id"]))
    print("School: {}".format(teachers[sim_teacher][i]["school_hashed_id"]))
    print("Posted: {}".format(teachers[sim_teacher][i]["project_posted_date"]))
    print("Funded: {}".format(teachers[sim_teacher][i]["project_funded_date"]))
    print("Grade : {}".format(teachers[sim_teacher][i]["project_grade_cat"]))
    print("Subj  : {}".format(teachers[sim_teacher][i]["project_subj_cat_tree"]))
    print("-- free text --")
    print("Title: {}".format(teachers[sim_teacher][i]["project_title"]))
    print("Essay1: {}".format(teachers[sim_teacher][i]["project_essay_one"]))
    print("Essay2: {}".format(teachers[sim_teacher][i]["project_essay_two"]))
    print(" ---- End of project - {} ----".format(i))
show_wc(t.index(sim_teacher))
# Out:
# Rank - 1
# Id - 78f90e8d0ffa6d1b9c58722e6f24e41f
#  Score - 0.9042580723762512
#  ---- Project num - 1 ----
# Project Id: f9644a098821f2aafcdfc2e553b00c82
# School: 6cb9226b69d533c240ca78d2f61789ad
# Posted: 2018-10-07
# Funded: 2018-10-24
# Grade : 0.0
# Subj  : Applied Learning
# -- free text --
# Title: Help Develop Digital Learners
# Essay1: teach kindergarten motivated curious learner student part magnet program efl stem love child eagerness participate educational activity learn new thing order enhance century skill need given opportunity explore digital world enthusiastic always prepared brand new adventure educational journey technology necessary learning
# Essay2: teach title school student free reduced lunch come low socioeconomic household many access internet home classroom working computer difficult student access day student need help century learning crucial child access early age adding laptop increase student exposure enabling enhance skill preparing successful future
#  ---- End of project - 0 ----
#
# ===Keywords===
# efl 0.304
# digital 0.239
# century 0.227
# access 0.216
# enhance 0.202
# educational 0.187
# enabling 0.185
# _early_development 0.17
# eagerness 0.152
# student 0.143

# %%
c = 1
sim_teacher, sim_score = sim_teachers[c]
print("Rank - {}\nId - {}\n Score - {}".format(c+1, sim_teacher, sim_score))
for i in range(len(teachers[sim_teacher])):
    print(" ---- Project num - {} ----".format(i+1))
    print("Project Id: {}".format(teachers[sim_teacher][i]["project_hashed_id"]))
    print("School: {}".format(teachers[sim_teacher][i]["school_hashed_id"]))
    print("Posted: {}".format(teachers[sim_teacher][i]["project_posted_date"]))
    print("Funded: {}".format(teachers[sim_teacher][i]["project_funded_date"]))
    print("Grade : {}".format(teachers[sim_teacher][i]["project_grade_cat"]))
    print("Subj  : {}".format(teachers[sim_teacher][i]["project_subj_cat_tree"]))
    print("-- free text --")
    print("Title: {}".format(teachers[sim_teacher][i]["project_title"]))
    print("Essay1: {}".format(teachers[sim_teacher][i]["project_essay_one"]))
    print("Essay2: {}".format(teachers[sim_teacher][i]["project_essay_two"]))
    print(" ---- End of project - {} ----".format(i))
show_wc(t.index(sim_teacher))
# Out:
# Rank - 2
# Id - 8200d45f4018ecd8346fb003e9d984fc
#  Score - 0.9037243127822876
#  ---- Project num - 1 ----
# Project Id: bf74253b3be86fe72a57effb4a4eb005
# School: c32e0d598c52426438a1fcd8d74c02ea
# Posted: 2018-07-04
# Funded: 2018-07-06
# Grade : 0.3333333333333333
# Subj  : Literacy & Language
# -- free text --
# Title: Powerful Mentor Texts Flexible Seating
# Essay1: grader student eager grow critical thinker problem solver student come variety background including military family household student need mentor text develop complex reading skill flexible seating option meet diverse learning need fourth grader enjoy participating mini reading lesson powerful mentor text help student continue grow reader also thrive choice motivation student feel special appreciated given opportunity choose sit classroom
# Essay2: flexible seating option allow student feel comfortable rigorous collaborative learning activity flexible seating give student choice allows take charge learning making sure student feel comfortable essential maximizing academic success student given choice engaged motivated bean bag bouncy chair used throughout school day allow student feel comfortable working together furthermore powerful engaging mentor text used introduce essential reading skill determining importance inferring summarizing student better able grasp skill using engaging text given opportunity revisit text understanding
#  ---- End of project - 0 ----
#
# ===Keywords===
# mentor 0.413
# text 0.346
# flexible 0.26
# seating 0.241
# powerful 0.212
# student 0.19
# grasp 0.155
# feel 0.15
# option 0.147
# comfortable 0.143

# %%
c = 2
sim_teacher, sim_score = sim_teachers[c]
print("Rank - {}\nId - {}\n Score - {}".format(c+1, sim_teacher, sim_score))
for i in range(len(teachers[sim_teacher])):
    print(" ---- Project num - {} ----".format(i+1))
    print("Project Id: {}".format(teachers[sim_teacher][i]["project_hashed_id"]))
    print("School: {}".format(teachers[sim_teacher][i]["school_hashed_id"]))
    print("Posted: {}".format(teachers[sim_teacher][i]["project_posted_date"]))
    print("Funded: {}".format(teachers[sim_teacher][i]["project_funded_date"]))
    print("Grade : {}".format(teachers[sim_teacher][i]["project_grade_cat"]))
    print("Subj  : {}".format(teachers[sim_teacher][i]["project_subj_cat_tree"]))
    print("-- free text --")
    print("Title: {}".format(teachers[sim_teacher][i]["project_title"]))
    print("Essay1: {}".format(teachers[sim_teacher][i]["project_essay_one"]))
    print("Essay2: {}".format(teachers[sim_teacher][i]["project_essay_two"]))
    print(" ---- End of project - {} ----".format(i))
show_wc(t.index(sim_teacher))
# Out:
# Rank - 3
# Id - 79c5185c46767fb5cb520af61fa751a0
#  Score - 0.902534008026123
#  ---- Project num - 1 ----
# Project Id: bb3f2a8afc33766bb9d8aee6e86ef183
# School: 2e676a02817a9f6e39976f02067a7aa0
# Posted: 2017-07-30
# Funded: 2017-08-01
# Grade : 0.3333333333333333
# Subj  : Literacy & Language, Math & Science
# -- free text --
# Title: Oh Places Grade Will Go Using Technology
# Essay1: imagine room full twenty eager grade student taken responsibility learning day student inquire engage self ass learning motivated expand knowledge gain insight increase endeavor student excited expand horizon experience new adventure exploration century resource however lot student unable gain new adventure due lack fund majority student struggle finding fund participate buy resource increase excitement learning many student participate backpack program lack fund participating anything extra classroom would love opportunity continue growth support make happen great place today day mountain wanting get way sue
# Essay2: implementing chromebooks classroom allow innovative individualized learning within daily classroom schedule student opportunity research develop project based interest utilizing chromebooks investing century technology student ability anything dream engineer photographer even teacher learning environment grant student ability explore enhance understanding beyond classroom dream student opportunity learn innovative classroom utilizing technology combined individualized attention student learn pace beneficial
#  ---- End of project - 0 ----
#
# ===Keywords===
# student 0.245
# utilizing 0.244
# century 0.194
# fund 0.183
# chrome 0.172
# classroom 0.161
# pace 0.155
# develop 0.155
# individualized 0.154
# technology 0.152
